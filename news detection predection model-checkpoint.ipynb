# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import re
import string

# %%
df=pd.read_csv("news.csv")

# %%
df
# Out:
#       Unnamed: 0                                              title  \
# 0           8476                       You Can Smell Hillary’s Fear
# 1          10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2           3608        Kerry to go to Paris in gesture of sympathy
# 3          10142  Bernie supporters on Twitter erupt in anger ag...
# 4            875   The Battle of New York: Why This Primary Matters
# ...          ...                                                ...
# 6330        4490  State Department says it can't find emails fro...
# 6331        8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332        8622  Anti-Trump Protesters Are Tools of the Oligarc...
# 6333        4021  In Ethiopia, Obama seeks progress on peace, se...
# 6334        4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# ...

# %%
real_news = df[df['label'] == "REAL"]  
fake_news = df[df['label'] == "FAKE"]

# %%
real_news.to_csv("real_news.csv", index=False)
fake_news.to_csv("fake_news.csv", index=False)

# %%
real_news=pd.read_csv("real_news.csv")
fake_news=pd.read_csv("fake_news.csv")

# %%
real_news
# Out:
#       Unnamed: 0                                              title  \
# 0           3608        Kerry to go to Paris in gesture of sympathy
# 1            875   The Battle of New York: Why This Primary Matters
# 2             95                  ‘Britain’s Schindler’ Dies at 106
# 3           4869  Fact check: Trump and Clinton at the 'commande...
# 4           2909  Iran reportedly makes new push for uranium con...
# ...          ...                                                ...
# 3166        2316  Alabama Lawmaker: Same-Sex Couples Don’t Deser...
# 3167        3262  GOP Senator David Perdue Jokes About Praying f...
# 3168        4490  State Department says it can't find emails fro...
# 3169        4021  In Ethiopia, Obama seeks progress on peace, se...
# 3170        4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label
# 0     U.S. Secretary of State John F. Kerry said Mon...  REAL
# ...

# %%
fake_news
# Out:
#       Unnamed: 0                                              title  \
# 0           8476                       You Can Smell Hillary’s Fear
# 1          10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2          10142  Bernie supporters on Twitter erupt in anger ag...
# 3           6903                                        Tehran, USA
# 4           7341  Girl Horrified At What She Watches Boyfriend D...
# ...          ...                                                ...
# 3159        6143  DOJ COMPLAINT: Comey Under Fire Over Partisan ...
# 3160        9337  Radio Derb Is On The Air–Leonardo And Brazil’s...
# 3161        8737  Assange claims ‘crazed’ Clinton campaign tried...
# 3162        8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 3163        8622  Anti-Trump Protesters Are Tools of the Oligarc...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# ...

# %%
real_news["class"]=1
fake_news["class"]=0

# %%
real_news.shape, fake_news.shape
# Out:
# ((3171, 5), (3164, 5))

# %%
fake_news_manual_testing=fake_news.tail(10)
for i in range(3163,3153,-1):
  fake_news.drop([i] , axis=0 , inplace=True)

# %%
real_news_manual_testing=real_news.tail(10)
for i in range(3170,3160,-1):
    real_news.drop([i] , axis=0, inplace=True)

# %%
real_news.shape,fake_news.shape
# Out:
# ((3161, 5), (3154, 5))

# %%
fake_news_manual_testing["class"]=0
real_news_manual_testing["class"]=1
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8424\619315447.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fake_news_manual_testing["class"]=0
# C:\Users\user\AppData\Local\Temp\ipykernel_8424\619315447.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_news_manual_testing["class"]=1

# %%
fake_news_manual_testing
# Out:
#       Unnamed: 0                                              title  \
# 3154        7991  BREAKING : Hillary Campaign Manager Deletes hi...
# 3155        9051  “Nothing Good Can Come of This Election”–and T...
# 3156       10200   List of Republicans opposing Trump | OffGuardian
# 3157       10009  Putin: Use of 'mythical' Russian military thre...
# 3158        8411  Will the Media Reset After the Election or Are...
# 3159        6143  DOJ COMPLAINT: Comey Under Fire Over Partisan ...
# 3160        9337  Radio Derb Is On The Air–Leonardo And Brazil’s...
# 3161        8737  Assange claims ‘crazed’ Clinton campaign tried...
# 3162        8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 3163        8622  Anti-Trump Protesters Are Tools of the Oligarc...
#
#                                                    text label  class
# 3154  BREAKING : Hillary Campaign Manager Deletes hi...  FAKE      0
# 3155  Posted on November 4, 2016 by Charles Hugh Smi...  FAKE      0
# ...

# %%
real_news_manual_testing
# Out:
#       Unnamed: 0                                              title  \
# 3161        2747  The “blame the left” crew: What the right’s ne...
# 3162        3717  Police Arrest Suspect In Charleston Church Sho...
# 3163        5205  Donald Trump’s collapse was caused by one big ...
# 3164        1303  Why Ted Cruz Has the Most to Lose in New Hamps...
# 3165        4214  Bernie Sanders says private meeting with Pope ...
# 3166        2316  Alabama Lawmaker: Same-Sex Couples Don’t Deser...
# 3167        3262  GOP Senator David Perdue Jokes About Praying f...
# 3168        4490  State Department says it can't find emails fro...
# 3169        4021  In Ethiopia, Obama seeks progress on peace, se...
# 3170        4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label  class
# 3161  It was inevitable that liberals would end up b...  REAL      1
# 3162  Police in Charleston, S.C., say a man they sus...  REAL      1
# ...

# %%
real_news.shape
# Out:
# (3161, 5)

# %%
manual_testing=pd.concat([fake_news_manual_testing, real_news_manual_testing], axis=0)
manual_testing. to_csv ("manual_testing.csv")

# %%
manual_testing
# Out:
#       Unnamed: 0                                              title  \
# 3154        7991  BREAKING : Hillary Campaign Manager Deletes hi...
# 3155        9051  “Nothing Good Can Come of This Election”–and T...
# 3156       10200   List of Republicans opposing Trump | OffGuardian
# 3157       10009  Putin: Use of 'mythical' Russian military thre...
# 3158        8411  Will the Media Reset After the Election or Are...
# 3159        6143  DOJ COMPLAINT: Comey Under Fire Over Partisan ...
# 3160        9337  Radio Derb Is On The Air–Leonardo And Brazil’s...
# 3161        8737  Assange claims ‘crazed’ Clinton campaign tried...
# 3162        8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 3163        8622  Anti-Trump Protesters Are Tools of the Oligarc...
# 3161        2747  The “blame the left” crew: What the right’s ne...
# 3162        3717  Police Arrest Suspect In Charleston Church Sho...
# 3163        5205  Donald Trump’s collapse was caused by one big ...
# ...

# %%
df_merge=pd.concat([fake_news,real_news],axis=0)
df_merge.head(10)
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2       10142  Bernie supporters on Twitter erupt in anger ag...
# 3        6903                                        Tehran, USA
# 4        7341  Girl Horrified At What She Watches Boyfriend D...
# 5        7041  Strong Solar Storm, Tech Risks Today | S0 News...
# 6        7623       10 Ways America Is Preparing for World War 3
# 7        7737  Shocking! Michele Obama & Hillary Caught Glamo...
# 8        8716  Hillary Clinton in HUGE Trouble After America ...
# 9       10348  Episode #160 – SUNDAY WIRE: ‘Hail to the Deplo...
#
#                                                 text label  class
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE      0
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE      0
# ...

# %%
df_merge.columns
# Out:
# Index(['Unnamed: 0', 'title', 'text', 'label', 'class'], dtype='object')

# %%
df=df_merge.drop(["Unnamed: 0","title","label"],axis=1)

# %%
df.isnull().sum()
# Out:
# text     0
# class    0
# dtype: int64

# %%
df
# Out:
#                                                    text  class
# 0     Daniel Greenfield, a Shillman Journalism Fello...      0
# 1     Google Pinterest Digg Linkedin Reddit Stumbleu...      0
# 2     — Kaydee King (@KaydeeKing) November 9, 2016 T...      0
# 3       \nI’m not an immigrant, but my grandparents ...      0
# 4     Share This Baylee Luciani (left), Screenshot o...      0
# ...                                                 ...    ...
# 3156  By failing to disclose his donations to the Cl...      1
# 3157  A debate over Islam -- first sparked by Donald...      1
# 3158  (CNN) Hillary Clinton forced Donald Trump onto...      1
# 3159  When Susan E. Rice took over as President Obam...      1
# 3160  (CNN) ISIS has claimed responsibility for the ...      1
#
# [6315 rows x 2 columns]

# %%
df=df.sample(frac=1)

# %%
df.head(10)
# Out:
#                                                    text  class
# 2790           The Dark Art of Political Intimidation        0
# 2129  ‘Though it appears as if rumors of capitalism’...      0
# 2006  Clinton lost her temper at an event on Thursda...      1
# 1855  U-M’s New ‘Chief Diversity Officer’ Will Colle...      0
# 782   But he still takes some time out for Twitter f...      1
# 2695  Why the Jobs Aren’t Coming Back. The “modern d...      0
# 2511  Texas police killed two gunmen on Sunday after...      1
# 1645  By Christina Sarich\nJordan — You’ve already h...      0
# 1096  ‹ › Arnaldo Rodgers is a trained and educated ...      0
# 2639  Sparks Fly Between Clinton And Sanders At Flin...      1

# %%
df.reset_index(inplace=True)
df.drop(["index"],axis=1,inplace=True)

# %%
df
# Out:
#                                                    text  class
# 0              The Dark Art of Political Intimidation        0
# 1     ‘Though it appears as if rumors of capitalism’...      0
# 2     Clinton lost her temper at an event on Thursda...      1
# 3     U-M’s New ‘Chief Diversity Officer’ Will Colle...      0
# 4     But he still takes some time out for Twitter f...      1
# ...                                                 ...    ...
# 6310  We Are Change \n\nThe debut album by Cahill vs...      0
# 6311    Hillary Clinton Appears Disoriented And Conf...      0
# 6312  Tweet Home » Silver » Silver News » It’s Going...      0
# 6313  The leading Republican presidential candidates...      1
# 6314  There’s nothing quite like playing in front of...      1
#
# [6315 rows x 2 columns]

# %%
def wordopt(text):
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub("\\W"," ",text) 
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)    
    return text

# %%
df["text"] = df["text"].apply(wordopt)

# %%
y=df["class"]
x=df["text"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorization = TfidfVectorizer()
xv_train = vectorization.fit_transform(x_train)
xv_test = vectorization.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

LR = LogisticRegression()
LR.fit(xv_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_lr=LR.predict(xv_test)

# %%
LR.score(xv_test, y_test)
# Out:
# 0.9183027232425586

# %%
LR.score(xv_train,y_train)
# Out:
# 0.9453125

# %%
print(classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92       800
#            1       0.93      0.90      0.92       779
#
#     accuracy                           0.92      1579
#    macro avg       0.92      0.92      0.92      1579
# weighted avg       0.92      0.92      0.92      1579

# %%
def output_lable(n):
    if n == 0:
        return "Fake News"
    elif n == 1:
        return "Not A Fake News"
    
def manual_testing(news):
    testing_news = {"text": [news]}
    new_def_test = pd.DataFrame(testing_news)
    new_def_test["text"] = new_def_test["text"].apply(wordopt) 
    new_x_test = new_def_test["text"]
    new_xv_test = vectorization.transform(new_x_test)
    pred_LR = LR.predict(new_xv_test)

    return output_lable(pred_LR[0])

# %%
news = str(input())
manual_testing(news)
# Out:
#  mia khalifa left porn industry
# 'Fake News'

# %%
news = str(input())
manual_testing(news)
# Out:
#  Finance Minister Muhammad Aurangzeb on Sunday said that there was “no such thing” as strategic state-owned enterprises (SOEs) as he stressed the need for privatisation.  He made the remarks at a pre-budget conference in Lahore, two days after Deputy Prime Minister Ishaq Dar said the government would limit its business only to strategic and essential SOEs under its domain but their number would be reduced from 40 after scrutiny.  Chairing the Cabinet Committee on Privatisation (CCoP) meeting, which was attended by the finance minister, Dar said privatisation of loss-making SOEs would be a priority.  The meeting noted that 40 SOEs were currently categorised as strategic or essential, but respective ministries would submit their details to the Cabinet Committee on State-Owned Enterprises (CCoSOE). The CCoSOE will determine the status of the SOEs to be categorised as strategic or essential entities.  Speaking on Sunday, Aurangzeb said: “There is no such as [a] strategic SOE.”  Talking a
# ...

# %%
news = str(input())
manual_testing(news)

# %%
news = str(input())
manual_testing(news)

# %%
news = str(input())
manual_testing(news)
